# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*- 
import sys, pprint, re,pickle
from collections import defaultdict

# %%
word_mapping_list=pickle.load(open("./word_mapping.mecab","rb"))

# %%
for w_pos in word_mapping_list[:1000]:
    if w_pos["word"]!=w_pos["原形"]:
        pprint.pprint(w_pos)
# Out:
# {'word': 'で',
#  '原形': 'だ',
#  '品詞': '助動詞',
#  '品詞細分類1': '*',
#  '品詞細分類2': '*',
#  '品詞細分類3': '*',
#  '活用型': '特殊・ダ',
#  '活用形': '連用形',
#  '発音': 'デ',
#  '読み': 'デ'}
# {'word': '生れ',
#  '原形': '生れる',
#  '品詞': '動詞',
#  '品詞細分類1': '自立',
#  '品詞細分類2': '*',
#  '品詞細分類3': '*',
#  '活用型': '一段',
#  '活用形': '連用形',
#  '発音': 'ウマレ',
#  '読み': 'ウマレ'}
# {'word': 'つか',
#  '原形': 'つく',
#  '品詞': '動詞',
#  '品詞細分類1': '自立',
#  '品詞細分類2': '*',
#  '品詞細分類3': '*',
#  '活用型': '五段・カ行イ音便',
#  '活用形': '未然形',
#  '発音': 'ツカ',
#  '読み': 'ツカ'}
# {'word': 'し',
#  '原形': 'する',
#  '品詞': '動詞',
#  '品詞細分類1': '自立',
#  '品詞細分類2': '*',
#  '品詞細分類3': '*',
#  '活用型': 'サ変・スル',
#  '活用形': '連用形',
#  '発音': 'シ',
#  '読み': 'シ'}
# {'word': 'ニャーニャー',
#  '原形': '*',
#  '品詞': '名詞',
#  '品詞細分類1': '一般',
#  '品詞細分類2': '*',
#  '品詞細分類3': '*',
#  '活用型': '*',
#  '活用形': '*'}
# {'word': '泣い',
#  '原形': '泣く',
#  '品詞': '動詞',
#  '品詞細分類1': '自立',
#  '品詞細分類2': '*',
#  '品詞細分類3': '*',
#  '活用型': '五段・カ行イ音便',
#  '活用形': '連用タ接続',
#  '発音': 'ナイ',
#  '読み': 'ナイ'}
# {'word': 'し',
# ...
